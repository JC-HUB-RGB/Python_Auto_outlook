# %%
import win32com.client as win32
import pandas as pd
import openpyxl
import os
from datetime import date

directorio_actual = "C:/Users/Jorge/Documents/Proyecto_outlook_python/Python_Auto_outlook/src"
hoy = date.today()
fecha_formateada = hoy.strftime("%m-%d-%y")
ruta_data = os.path.join(directorio_actual,"..","data",fecha_formateada+"_ECS_Factoring_NOARecdDate" ".xlsx")
print(ruta_data)
df = pd.read_excel(ruta_data)
df.columns
# Out:
# C:/Users/Jorge/Documents/Proyecto_outlook_python/Python_Auto_outlook/src\..\data\05-17-26_ECS_Factoring_NOARecdDate.xlsx
# Index(['NOA Rec Date', 'NOA Assigment', 'NOA Sent', 'NOA Sent User',
#        'Debtor NOA Document', 'Total Debt', 'Client Name', 'MCNumber', 'CSR',
#        'CSR.1', 'Office', 'Debtor Name', 'Debtor Phone', 'Debtor Phone.1',
#        'Debtor Email Address', 'Notice', 'Notice Contact Email',
#        'NOA Entered Date', 'Last Inv Date', 'Last Inv #', 'Last PO #',
#        'First Inv Date', 'Relationship Age', 'First Funded', 'Client Age',
#        'Attention Note', 'Warning Note', 'Funded Balance',
#        'Non Funded Balance'],
#       dtype='str')

# %%
df[[ 'Total Debt','Client Name','MCNumber', 'CSR', 'Debtor Name', 'Debtor Phone', 'Debtor Email Address', 'Last PO #', 'Attention Note', 'Warning Note' ]]
# Out:
#       Total Debt                                    Client Name  MCNumber  \
# 0          750.0                         Chip Shot Trucking LLC   1247517
# 1         1425.0                                  Big Wings LLC  1021935.
# 2         3300.0                           Crocodile Cargo Corp   1801515
# 3         2100.0                                     Oxiana LLC   1482647
# 4          750.0                      Black Horse Transport Inc   1137495
# ...          ...                                            ...       ...
# 1558      1050.0  C & J Transport (dba of Jose Hector M Romero)   1125808
# 1559      1400.0                         Sky Reign Trucking LLC   1445353
# 1560       850.0                      D & B Logistics Group LLC   1644074
# 1561      2700.0                  Aces and Eights Transport Inc   1013972
# 1562      2600.0                                 FSD Freight Co    981989
#
#            CSR                         Debtor Name  Debtor Phone  \
# ...

# %%
df.drop(columns=['NOA Rec Date', 'NOA Assigment', 'NOA Sent', 'NOA Sent User','Debtor NOA Document','CSR.1', 'Office','Notice', 'Notice Contact Email','NOA Entered Date', 'Last Inv Date', 'Last Inv #', 'First Inv Date', 'Relationship Age', 'First Funded', 'Client Age', 'Funded Balance', 'Non Funded Balance'], axis='columns', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df.drop(columns=['NOA Rec Date', 'NOA Assigment', 'NOA Sent', 'NOA Sent User','Debtor NOA Document','CSR.1', 'Office','Notice', 'Notice Contact Email','NOA Entered Date', 'Last Inv Date', 'Last Inv #', 'First Inv Date', 'Relationship Age', 'First Funded', 'Client Age', 'Funded Balance', 'Non Funded Balance'], axis='columns', inplace=True)
#       2
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\frame.py:6300, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6296                 weight  250.0   150.0
#    6297         falcon  speed   320.0   250.0
#    6298                 weight  1.0     0.8
#    6299         """
# -> 6300         return super().drop(
#    6301             labels=labels,
#    6302             axis=axis,
# ...

# %%
df.columns
